# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium 
import requests
import json
from geopy.distance import geodesic

# %%
hdb_df = pd.read_csv("final_hdb_resale_prices.csv")

# %%
hdb_final_df = hdb_df.iloc[:,1:]

# %%
# focusing on these three years
years_needed = [2020,2021,2022]
hdb_latest_df = hdb_final_df.loc[hdb_final_df['year'].isin(years_needed)]

# %%
hdb_latest_df = hdb_latest_df.reset_index()
hdb_latest_df = hdb_latest_df.drop(columns=["index"])

# %%
# left skewed
plt.hist(hdb_latest_df['cpi_adjusted_price'])
# Out:
# (array([2.6590e+03, 1.9285e+04, 2.6828e+04, 1.6171e+04, 7.7450e+03,
#         3.5940e+03, 1.1440e+03, 2.7800e+02, 1.0800e+02, 2.2000e+01]),
#  array([ 139599.6  ,  276523.348,  413447.096,  550370.844,  687294.592,
#          824218.34 ,  961142.088, 1098065.836, 1234989.584, 1371913.332,
#         1508837.08 ]),
#  <BarContainer object of 10 artists>)

# %%
hdb_latest_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xk/05mnlwt50k19lbm41jbfty7w0000gn/T/ipykernel_93430/1310336258.py in <module>
# ----> 1 hdb_latest_df
#
# NameError: name 'hdb_latest_df' is not defined

# %%
# checking for null values
hdb_latest_df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# resale_price                0
# Latitude                    0
# Longitude                   0
# cpi_multiplier              0
# cpi_adjusted_price          0
# year                        0
# no.of bto                   0
# resale application          0
# demand ratio                0
# remaining_lease_months      0
# address                     0
# Distance to nearest MRT     0
# Distance to CBD             0
# Distance to nearest mall    0
# isMatureEstate              0
# dtype: int64

# %%
# checking for outliers
hdb_latest_df.boxplot(figsize=(30,10))
# Out:
# <AxesSubplot:>
