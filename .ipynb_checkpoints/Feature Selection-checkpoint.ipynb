# %% [markdown]
# ### Feature Selection

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold as sk
from sklearn.tree import DecisionTreeClassifier as dt
from sklearn.preprocessing import StandardScaler, scale
from sklearn.metrics import accuracy_score as acs

# %%
hdb_resale_prices = pd.read_csv("final_hdb_resale_prices.csv")
hdb_resale_prices.head()
# Out:
#    Unnamed: 0    month        town flat_type  storey_range  floor_area_sqm  \
# 0           0  2017-01  ANG MO KIO    3 ROOM             2            67.0
# 1           1  2017-01  ANG MO KIO    3 ROOM             2            67.0
# 2           2  2017-01  ANG MO KIO    3 ROOM             5            68.0
# 3           3  2017-01  ANG MO KIO    3 ROOM             2            67.0
# 4           4  2017-01  ANG MO KIO    3 ROOM             2            68.0
#
#        flat_model  resale_price  Latitude   Longitude  ...  year  no.of bto  \
# 0  New Generation      250000.0  1.370943  103.837975  ...  2017      14464
# 1  New Generation      262000.0  1.380709  103.835368  ...  2017      14464
# 2  New Generation      265000.0  1.366201  103.857201  ...  2017      14464
# 3  New Generation      265000.0  1.381041  103.835132  ...  2017      14464
# 4  New Generation      275000.0  1.376807  103.842018  ...  2017      14464
#
#    resale application  demand ratio  remaining_lease_months  \
# 0             20894.0          1.02                     727
# 1             20894.0          1.02                     749
# 2             20894.0          1.02                     744
# 3             20894.0          1.02                     749
# 4             20894.0          1.02                     756
#
#                  address  Distance to nearest MRT Distance to CBD  \
# 0   108 ANG MO KIO AVE 4               166.825954     9696.234644
# 1   602 ANG MO KIO AVE 5               532.155055    10808.143550
# 2  465 ANG MO KIO AVE 10               945.375055     9087.920590
# 3   601 ANG MO KIO AVE 5               498.419646    10848.697720
# 4   150 ANG MO KIO AVE 5               636.982785    10284.079570
#
#    Distance to nearest mall  isMatureEstate
# 0                896.944633               1
# 1               1527.724531               1
# 2                880.143181               1
# 3               1571.446900               1
# 4                695.573226               1
#
# [5 rows x 22 columns]

# %%
hdb_resale_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143259 entries, 0 to 143258
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                143259 non-null  int64
#  1   month                     143259 non-null  object
#  2   town                      143259 non-null  object
#  3   flat_type                 143259 non-null  object
#  4   storey_range              143259 non-null  int64
#  5   floor_area_sqm            143259 non-null  float64
#  6   flat_model                143259 non-null  object
#  7   resale_price              143259 non-null  float64
#  8   Latitude                  143259 non-null  float64
#  9   Longitude                 143259 non-null  float64
#  10  cpi_multiplier            143259 non-null  float64
#  11  cpi_adjusted_price        143259 non-null  float64
#  12  year                      143259 non-null  int64
#  13  no.of bto                 143259 non-null  int64
#  14  resale application        141109 non-null  float64
#  15  demand ratio              141109 non-null  float64
#  16  remaining_lease_months    143259 non-null  int64
#  17  address                   143259 non-null  object
#  18  Distance to nearest MRT   143259 non-null  float64
#  19  Distance to CBD           143259 non-null  float64
#  20  Distance to nearest mall  143259 non-null  float64
#  21  isMatureEstate            143259 non-null  int64
# dtypes: float64(11), int64(6), object(5)
# memory usage: 24.0+ MB

# %%
hdb_resale_prices = hdb_resale_prices[hdb_resale_prices['year'] != 2017]
hdb_resale_prices = hdb_resale_prices[hdb_resale_prices['year'] != 2018]
hdb_resale_prices = hdb_resale_prices[hdb_resale_prices['year'] != 2019]
hdb_resale_prices = hdb_resale_prices[hdb_resale_prices['year'] != 2023]
hdb_resale_prices
# Out:
#         Unnamed: 0    month        town  flat_type  storey_range  \
# 63275        63275  2020-01  ANG MO KIO     3 ROOM             5
# 63276        63276  2020-01  ANG MO KIO     3 ROOM            20
# 63277        63277  2020-01  ANG MO KIO     3 ROOM             2
# 63278        63278  2020-01  ANG MO KIO     3 ROOM             5
# 63279        63279  2020-01  ANG MO KIO     3 ROOM             8
# ...            ...      ...         ...        ...           ...
# 141104      141104  2022-12      YISHUN  EXECUTIVE             8
# 141105      141105  2022-12      YISHUN  EXECUTIVE             8
# 141106      141106  2022-12      YISHUN  EXECUTIVE             8
# 141107      141107  2022-12      YISHUN  EXECUTIVE            11
# 141108      141108  2022-12      YISHUN  EXECUTIVE             5
#
#         floor_area_sqm      flat_model  resale_price  Latitude   Longitude  \
# 63275             73.0  New Generation      265000.0  1.365445  103.842715
# 63276             70.0         Model A      470000.0  1.365561  103.845169
# 63277             73.0  New Generation      230000.0  1.365098  103.847381
# 63278             73.0  New Generation      280000.0  1.366197  103.841505
# 63279             68.0  New Generation      220000.0  1.372032  103.857625
# ...                ...             ...           ...       ...         ...
# 141104           146.0      Maisonette      845000.0  1.425404  103.844843
# 141105           142.0       Apartment      782000.0  1.421335  103.837437
# 141106           142.0       Apartment      770888.0  1.421335  103.837437
# 141107           146.0      Maisonette      788000.0  1.421334  103.836318
# 141108           142.0       Apartment      740000.0  1.421334  103.836318
#
#         ...  year  no.of bto  resale application  demand ratio  \
# 63275   ...  2020       7314             26436.0          1.13
# 63276   ...  2020       7314             26436.0          1.13
# 63277   ...  2020       7314             26436.0          1.13
# 63278   ...  2020       7314             26436.0          1.13
# 63279   ...  2020       7314             26436.0          1.13
# ...     ...   ...        ...                 ...           ...
# 141104  ...  2022      20064             30370.0          1.14
# 141105  ...  2022      20064             30370.0          1.14
# 141106  ...  2022      20064             30370.0          1.14
# 141107  ...  2022      20064             30370.0          1.14
# 141108  ...  2022      20064             30370.0          1.14
#
#         remaining_lease_months                address  \
# 63275                      667   208 ANG MO KIO AVE 1
# 63276                     1100  307C ANG MO KIO AVE 1
# 63277                      676   319 ANG MO KIO AVE 1
# 63278                      663   216 ANG MO KIO AVE 1
# 63279                      708  556 ANG MO KIO AVE 10
# ...                        ...                    ...
# 141104                     780     355 YISHUN RING RD
# 141105                     766       643 YISHUN ST 61
# 141106                     766       643 YISHUN ST 61
# 141107                     768       606 YISHUN ST 61
# 141108                     768       606 YISHUN ST 61
#
#         Distance to nearest MRT Distance to CBD  Distance to nearest mall  \
# 63275                908.970521     9026.295266                775.593122
# 63276                687.185319     9015.122154                561.028714
# 63277                586.980690     8949.443986                489.978660
# 63278                800.631299     9123.690385                806.304304
# 63279                927.322849     9734.443856               1059.121690
# ...                         ...             ...                       ...
# 141104              1182.415251    15623.766720                908.910361
# 141105               661.035324    15234.077610                568.606554
# 141106               661.035324    15234.077610                568.606554
# 141107               573.471701    15246.853760                668.020144
# 141108               573.471701    15246.853760                668.020144
#
#         isMatureEstate
# 63275                1
# 63276                1
# 63277                1
# 63278                1
# 63279                1
# ...                ...
# 141104               0
# 141105               0
# 141106               0
# 141107               0
# 141108               0
#
# [77834 rows x 22 columns]

# %%
columns_to_drop = ['Unnamed: 0','month','town','flat_type','flat_model','address','Latitude','Longitude','cpi_multiplier','year']
hdb_resale_prices = hdb_resale_prices.drop(columns=columns_to_drop)

# %%
hdb_resale_prices['cpi_adjusted_price_per_sqm'] = hdb_resale_prices["cpi_adjusted_price"] / hdb_resale_prices["floor_area_sqm"]

# %%
 hdb_resale_prices = hdb_resale_prices.drop(columns=['cpi_adjusted_price','resale_price'])

# %%
hdb_resale_prices.shape
# Out:
# (77834, 11)

# %%
hdb_resale_prices.describe()
# Out:
#        storey_range  floor_area_sqm     no.of bto  resale application  \
# count  77834.000000    77834.000000  77834.000000        77834.000000
# mean       8.866922       98.424730  13989.294216        27763.372459
# std        6.116736       23.134662   5057.660156         1860.110229
# min        2.000000       51.000000   7314.000000        26436.000000
# 25%        5.000000       84.000000   7314.000000        26436.000000
# 50%        8.000000       93.000000  13756.000000        26436.000000
# 75%       11.000000      113.000000  20064.000000        30370.000000
# max       50.000000      243.000000  20064.000000        30370.000000
#
#        demand ratio  remaining_lease_months  Distance to nearest MRT  \
# count  77834.000000            77834.000000             77834.000000
# mean       1.052323              899.000039               845.200570
# std        0.108772              172.516234               466.462492
# min        0.910000              516.000000                31.759538
# 25%        0.910000              755.000000               481.807434
# 50%        1.130000              899.000000               759.557518
# 75%        1.140000             1092.000000              1128.696508
# max        1.140000             1173.000000              3646.118783
#
#        Distance to CBD  Distance to nearest mall  isMatureEstate  \
# count     77834.000000              77834.000000    77834.000000
# mean      12235.943008                654.394035        0.396459
# std        4325.466083                369.353092        0.489165
# min         527.673362                  0.000708        0.000000
# 25%        9614.007911                383.961774        0.000000
# 50%       13202.489430                583.578305        0.000000
# 75%       15150.006070                864.744147        1.000000
# max       23064.390350               3999.391261        1.000000
#
#        cpi_adjusted_price_per_sqm
# count                77834.000000
# mean                  5369.706969
# std                   1458.075585
# min                   2083.576119
# 25%                   4399.147059
# 50%                   5083.842222
# 75%                   5944.059310
# max                  15674.862366

# %% [markdown]
# Extra Trees Regressor can also be used for feature selection. It can be used to identify the most important variables that contribute to the prediction of the target variable.

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()  
model.fit(hdb_resale_prices.iloc[:,0:10],hdb_resale_prices.iloc[:,-1]  )

feat_importances = pd.Series(model.feature_importances_,index = hdb_resale_prices.columns[0:10])
feat_importances=feat_importances.sort_values(ascending=True)
feat_importances.plot(kind='barh',fontsize =10)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

#these steps are required only for numeric input variablesc
numeric_cols = hdb_resale_prices.columns.values
#fill missing and standardise
for col in numeric_cols:
        hdb_resale_prices[col] = scaler.fit_transform(hdb_resale_prices[[col]])

# %%
plt.figure(figsize=(16, 6))
corr_df = hdb_resale_prices.corr()
hm = sns.heatmap(corr_df , annot=True)

# %% [markdown]
# - Demand ratio play low importance in determining cpi adjusted price per sqm
#
# - Lat and long are dropped as it is just the location of the flat
#
# - cpi multiplier is not needed as it is used to tabulate other information
#
# - year of resale and distance to CBD has low importance.

# %%
# cols_to_drops=['demand ratio','Distance to nearest mall','Latitude','Longitude','cpi_multiplier','year','Distance to CBD']
cols_to_drops=['demand ratio','Distance to nearest mall']
hdb_model_data = hdb_resale_prices.drop(columns=cols_to_drops)
hdb_model_data
# Out:
#         storey_range  floor_area_sqm  no.of bto  resale application  \
# 63275         0.0625        0.114583        0.0                 0.0
# 63276         0.3750        0.098958        0.0                 0.0
# 63277         0.0000        0.114583        0.0                 0.0
# 63278         0.0625        0.114583        0.0                 0.0
# 63279         0.1250        0.088542        0.0                 0.0
# ...              ...             ...        ...                 ...
# 141104        0.1250        0.494792        1.0                 1.0
# 141105        0.1250        0.473958        1.0                 1.0
# 141106        0.1250        0.473958        1.0                 1.0
# 141107        0.1875        0.494792        1.0                 1.0
# 141108        0.0625        0.473958        1.0                 1.0
#
#         remaining_lease_months  Distance to nearest MRT  Distance to CBD  \
# 63275                 0.229833                 0.242702         0.377101
# 63276                 0.888889                 0.181339         0.376605
# 63277                 0.243531                 0.153615         0.373691
# 63278                 0.223744                 0.212727         0.381423
# 63279                 0.292237                 0.247779         0.408523
# ...                        ...                      ...              ...
# 141104                0.401826                 0.318357         0.669844
# 141105                0.380518                 0.174104         0.652553
# 141106                0.380518                 0.174104         0.652553
# 141107                0.383562                 0.149878         0.653120
# 141108                0.383562                 0.149878         0.653120
#
#         isMatureEstate  cpi_adjusted_price_per_sqm
# 63275              1.0                    0.113027
# 63276              1.0                    0.339299
# 63277              1.0                    0.077851
# 63278              1.0                    0.128102
# 63279              1.0                    0.084059
# ...                ...                         ...
# 141104             0.0                    0.299814
# 141105             0.0                    0.277843
# 141106             0.0                    0.271717
# 141107             0.0                    0.269248
# 141108             0.0                    0.254687
#
# [77834 rows x 9 columns]

# %%
hdb_model_data.to_csv('hdb_model_data.csv',index=False)
